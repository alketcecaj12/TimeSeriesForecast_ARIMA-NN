# %% [markdown]
# ### import libs

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# ### import data

# %%
data = pd.read_csv("C:/Users/alket/anaconda3/envs/tsml/Bologna-2020-Marzo.csv", sep = ";")

# %%
data
# Out:
#    LOCALITA       DATA  TMEDIA °C  TMIN °C  TMAX °C  PUNTORUGIADA °C  \
# 0   Bologna   1/3/2020          7        4        9                5
# 1   Bologna   2/3/2020          9        2       16                6
# 2   Bologna   3/3/2020          7        3       10                6
# 3   Bologna   4/3/2020          8        5       12                4
# 4   Bologna   5/3/2020          8        3       13                3
# 5   Bologna   6/3/2020          8        4       12                5
# 6   Bologna   7/3/2020          9        6       13                5
# 7   Bologna   8/3/2020          9        4       14                3
# 8   Bologna   9/3/2020          8        4       14                3
# 9   Bologna  10/3/2020          9        4       16                2
# 10  Bologna  11/3/2020         12        4       19                3
# 11  Bologna  12/3/2020         11        4       18                6
# 12  Bologna  13/3/2020         14        9       19                9
# ...

# %%
t_media = data['TMEDIA °C']
t_media
# Out:
# 0      7
# 1      9
# 2      7
# 3      8
# 4      8
# 5      8
# 6      9
# 7      9
# 8      8
# 9      9
# 10    12
# 11    11
# 12    14
# 13    12
# 14     8
# 15     8
# 16    10
# 17    12
# 18    14
# 19    14
# 20    13
# 21    11
# 22     6
# 23     5
# 24     6
# 25     3
# 26     7
# 27    12
# 28    13
# 29    10
# 30     7
# Name: TMEDIA °C, dtype: int64

# %%
plt.figure(figsize = (20, 5))
plt.plot(t_media)
plt.show()

# %%
t_media.min()
# Out:
# 3

# %%
t_media.max()
# Out:
# 14

# %%
t_media.mean()
# Out:
# 9.35483870967742

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   LOCALITA           31 non-null     object
#  1   DATA               31 non-null     object
#  2   TMEDIA °C          31 non-null     int64
#  3   TMIN °C            31 non-null     int64
#  4   TMAX °C            31 non-null     int64
#  5   PUNTORUGIADA °C    31 non-null     int64
#  6   UMIDITA %          31 non-null     int64
#  7   VISIBILITA km      31 non-null     int64
#  8   VENTOMEDIA km/h    31 non-null     int64
#  9   VENTOMAX km/h      31 non-null     int64
#  10  RAFFICA km/h       31 non-null     int64
#  11  PRESSIONESLM mb    31 non-null     int64
#  12  PRESSIONEMEDIA mb  31 non-null     int64
#  13  PIOGGIA mm         31 non-null     int64
#  14  FENOMENI           13 non-null     object
# dtypes: int64(12), object(3)
# memory usage: 3.8+ KB

# %%
data['DATA'] = pd.to_datetime(data['DATA'])
data = data.set_index(data['DATA'])

# %%
data
# Out:
#            LOCALITA       DATA  TMEDIA °C  TMIN °C  TMAX °C  PUNTORUGIADA °C  \
# DATA
# 2020-01-03  Bologna 2020-01-03          7        4        9                5
# 2020-02-03  Bologna 2020-02-03          9        2       16                6
# 2020-03-03  Bologna 2020-03-03          7        3       10                6
# 2020-04-03  Bologna 2020-04-03          8        5       12                4
# 2020-05-03  Bologna 2020-05-03          8        3       13                3
# 2020-06-03  Bologna 2020-06-03          8        4       12                5
# 2020-07-03  Bologna 2020-07-03          9        6       13                5
# 2020-08-03  Bologna 2020-08-03          9        4       14                3
# 2020-09-03  Bologna 2020-09-03          8        4       14                3
# 2020-10-03  Bologna 2020-10-03          9        4       16                2
# 2020-11-03  Bologna 2020-11-03         12        4       19                3
# ...

# %%
plt.figure(figsize = (20, 4))
plt.plot(data['TMEDIA °C'])
plt.show()

# %%
sub_tmedia = t_media.values
sub_tmedia = sub_tmedia[:10]
sub_tmedia
# Out:
# array([7, 9, 7, 8, 8, 8, 9, 9, 8, 9], dtype=int64)

# %%
plt.figure(figsize =(20, 4))
plt.plot(sub_tmedia)
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
tmedia = data['TMEDIA °C']

# %%
decomp_result =seasonal_decompose(tmedia, model = 'additive', freq= 1)
# Out:
# <ipython-input-20-61c3ecf1f8a5>:1: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   decomp_result =seasonal_decompose(tmedia, model = 'additive', freq= 1)

# %%
with plt.rc_context():
    plt.rc("figure", figsize = (20, 8))
    decomp_result.plot()
    plt.show()
